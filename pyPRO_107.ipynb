# %% [markdown]
# # Working with Pandas DataDrames

# %%
# Import the pandas package
import pandas as pd

# %% [markdown]
# ### 1. Load Data Frames/ Data files
# Pandas makes it easy to load/import datasets in deferent formats. Some of this format include:
# csv, xlsx, txt, sql, mysql, json, sav, sas...
#
# The most common formats are csv-which is most recomended for large datasets- and xlsx.
#
# Please makesure you download the datafiles used in this script in our [pyPRO github account](https://github.com/pyPRO2019/pyPRO_001)

# %%
pwd ## Checking the working directorty
# Out:
# 'C:\\Users\\DMuturi\\pyPRO_001'

# %% [markdown]
# we need to change our working directory to the folder that contains the datasets that wehave just downloaded.

# %%
cd C:\TUSHIAZ\pyPRO\Datasets
# Out:
# C:\TUSHIAZ\pyPRO\Datasets

# %%
pwd
# Out:
# 'C:\\TUSHIAZ\\pyPRO\\Datasets'

# %% [markdown]
# we load data using the **read** function available in pandas
#
# **1. Read excell file**

# %%
df=pd.read_excel('Ads_Data.xlsx') ## Shift ++Tab to get detailed help

# %% [markdown]
# Viewing the first 3 columns of the data we have just loaded

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %% [markdown]
#  **2. Csv Data**
#
#  we use the same pandas read funtion but we specify _csv  while importing csv files

# %%
df=pd.read_csv('Ads_Data.csv')
df.tail(3)### Viewing the last 3 columns of our dataframe
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 37  15689425    Male   30            49000          0
# 38  15671766  Female   26            72000          0
# 39  15782806  Female   27            31000          0

# %% [markdown]
# **3. Loading the text Data**
#
# We shall use this method when doing some text analysis like sentiment analysis

# %%
file=open('txt_Data.txt',mode='r') ### open the file in your work frame
text=file.read() ## Read the content pof the file
file.close() ## Close the used file 
text # Print the imported file
# Out:
# 'Review \nWow... Loved this place.        1\nCrust is not good.      0\nNot tasty and the texture was just nasty.       0\nStopped by during the late May bank holiday off Rick Steve recommendation and loved it. 1\nThe selection on the menu was great and so were the prices.     1\nNow I am getting angry and I want my damn pho.  0\nHoneslty it didn\'t taste THAT fresh.)   0\nThe potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer. 0\nThe fries were great too.       1\nA great touch.  1\nService was very prompt.        1\nWould not go back.      0\nThe cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.     0\n"I tried the Cape Cod ravoli, chicken, with cranberry...mmmm!    1"\nI was disgusted because I was pretty sure that was human hair.  0\nI was shocked because no signs indicate cash only.      0\nHighly recommended.     1\nWaitress was a little slow in service.  0\n"This place is not 
# ...

# %% [markdown]
# ### Working with data frames
# #### Exploring the data

# %% [markdown]
# Getting the information about Your dataset and columns datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
# User ID            40 non-null int64
# Gender             40 non-null object
# Age                40 non-null int64
# EstimatedSalary    40 non-null int64
# Purchased          40 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# This informs us:
# - The dataset is a pandas dataframe
# - We have 40 rows and 5 columns
# - 4 of the columns are integers and one is categorical (gender - object)
# - No missing values

# %%
df.head() ## The fist five rows
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.tail() ## The last 5 rows
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 35  15713144    Male   35            27000          0
# 36  15690188  Female   33            28000          0
# 37  15689425    Male   30            49000          0
# 38  15671766  Female   26            72000          0
# 39  15782806  Female   27            31000          0

# %% [markdown]
# Summary statistics for the numerical variables only in the dataset

# %%
df.describe()
# Out:
#             User ID        Age  EstimatedSalary  Purchased
# count  4.000000e+01  40.000000        40.000000  40.000000
# mean   1.568255e+07  33.200000     49375.000000   0.350000
# std    6.723272e+04   9.808944     31888.980092   0.483046
# min    1.557077e+07  18.000000     16000.000000   0.000000
# 25%    1.562365e+07  26.750000     25750.000000   0.000000
# 50%    1.569251e+07  30.500000     42000.000000   0.000000
# 75%    1.572884e+07  45.000000     72500.000000   1.000000
# max    1.581094e+07  49.000000    150000.000000   1.000000

# %% [markdown]
# Summary statistics for the cartegorical variables only

# %%
df.describe(include=object)
# Out:
#        Gender
# count      40
# unique      2
# top      Male
# freq       23

# %% [markdown]
# Summary Statistic for all variables in the dataset

# %%
df.describe(include='all')
# Out:
#              User ID Gender        Age  EstimatedSalary  Purchased
# count   4.000000e+01     40  40.000000        40.000000  40.000000
# unique           NaN      2        NaN              NaN        NaN
# top              NaN   Male        NaN              NaN        NaN
# freq             NaN     23        NaN              NaN        NaN
# mean    1.568255e+07    NaN  33.200000     49375.000000   0.350000
# std     6.723272e+04    NaN   9.808944     31888.980092   0.483046
# min     1.557077e+07    NaN  18.000000     16000.000000   0.000000
# 25%     1.562365e+07    NaN  26.750000     25750.000000   0.000000
# 50%     1.569251e+07    NaN  30.500000     42000.000000   0.000000
# 75%     1.572884e+07    NaN  45.000000     72500.000000   1.000000
# max     1.581094e+07    NaN  49.000000    150000.000000   1.000000

# %%
df.T # Transpose
# Out:
#                        0         1         2         3         4         5   \
# User ID          15624510  15810944  15668575  15603246  15804002  15728773
# Gender               Male      Male    Female    Female      Male      Male
# Age                    19        35        26        27        19        27
# EstimatedSalary     19000     20000     43000     57000     76000     58000
# Purchased               0         0         0         0         0         0
#
#                        6         7         8         9   ...        30  \
# User ID          15598044  15694829  15600575  15727311  ...  15581198
# Gender             Female    Female      Male    Female  ...      Male
# Age                    27        32        25        35  ...        31
# EstimatedSalary     84000    150000     33000     65000  ...     74000
# Purchased               0         1         0         0  ...         0
#
#                        31        32        33        34        35        36  \
# ...

# %% [markdown]
# The dimensions of the data

# %%
(row,col)=df.shape
print(df.shape)
print('The columns are: {} and the rows are: {}'.format(col,row))
# Out:
# (40, 5)
# The columns are: 5 and the rows are: 40

# %%
## Total observations
df.size
# Out:
# 200

# %%
## Converting the data into arrey format
df.values
# Out:
# array([[15624510, 'Male', 19, 19000, 0],
#        [15810944, 'Male', 35, 20000, 0],
#        [15668575, 'Female', 26, 43000, 0],
#        [15603246, 'Female', 27, 57000, 0],
#        [15804002, 'Male', 19, 76000, 0],
#        [15728773, 'Male', 27, 58000, 0],
#        [15598044, 'Female', 27, 84000, 0],
#        [15694829, 'Female', 32, 150000, 1],
#        [15600575, 'Male', 25, 33000, 0],
#        [15727311, 'Female', 35, 65000, 0],
#        [15570769, 'Female', 26, 80000, 0],
#        [15606274, 'Female', 26, 52000, 0],
#        [15746139, 'Male', 20, 86000, 0],
#        [15704987, 'Male', 32, 18000, 0],
#        [15628972, 'Male', 18, 82000, 0],
#        [15697686, 'Male', 29, 80000, 0],
#        [15733883, 'Male', 47, 25000, 1],
#        [15617482, 'Male', 45, 26000, 1],
#        [15704583, 'Male', 46, 28000, 1],
#        [15621083, 'Female', 48, 29000, 1],
#        [15649487, 'Male', 45, 22000, 1],
#        [15736760, 'Female', 47, 49000, 1],
# ...

# %%
## Copyinh the dataset
data_copy=df.copy()
data_copy
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   19            19000          0
# 1   15810944    Male   35            20000          0
# 2   15668575  Female   26            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   19            76000          0
# 5   15728773    Male   27            58000          0
# 6   15598044  Female   27            84000          0
# 7   15694829  Female   32           150000          1
# 8   15600575    Male   25            33000          0
# 9   15727311  Female   35            65000          0
# 10  15570769  Female   26            80000          0
# 11  15606274  Female   26            52000          0
# 12  15746139    Male   20            86000          0
# 13  15704987    Male   32            18000          0
# 14  15628972    Male   18            82000          0
# 15  15697686    Male   29            80000          0
# ...

# %%
### Sorting the dataset by a specific variable
df.sort_values(by='Age',ascending=True)
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 14  15628972    Male   18            82000          0
# 0   15624510    Male   19            19000          0
# 4   15804002    Male   19            76000          0
# 12  15746139    Male   20            86000          0
# 32  15573452  Female   21            16000          0
# 8   15600575    Male   25            33000          0
# 2   15668575  Female   26            43000          0
# 38  15671766  Female   26            72000          0
# 10  15570769  Female   26            80000          0
# 11  15606274  Female   26            52000          0
# 34  15724858    Male   27            90000          0
# 31  15729054  Female   27           137000          1
# 39  15782806  Female   27            31000          0
# 3   15603246  Female   27            57000          0
# 5   15728773    Male   27            58000          0
# 6   15598044  Female   27            84000          0
# ...

# %% [markdown]
# ## Math Functions
# note that this functions apply only for numerical variabls in the dataframe

# %%
## Mean
df.mean()
# Out:
# User ID            1.568255e+07
# Age                3.320000e+01
# EstimatedSalary    4.937500e+04
# Purchased          3.500000e-01
# dtype: float64

# %%
## Median
df.median()
# Out:
# User ID            15692508.5
# Age                      30.5
# EstimatedSalary       42000.0
# Purchased                 0.0
# dtype: float64

# %%
## Maximums
df.max()
# Out:
# User ID            15810944
# Gender                 Male
# Age                      49
# EstimatedSalary      150000
# Purchased                 1
# dtype: object

# %%
### Column Totals
df.sum()
# Out:
# User ID                                                    627302083
# Gender             MaleMaleFemaleFemaleMaleMaleFemaleFemaleMaleFe...
# Age                                                             1328
# EstimatedSalary                                              1975000
# Purchased                                                         14
# dtype: object

# %%
## distinct elements
df.nunique()
# Out:
# User ID            40
# Gender              2
# Age                19
# EstimatedSalary    32
# Purchased           2
# dtype: int64

# %%
## Counts
df.count()
# Out:
# User ID            40
# Gender             40
# Age                40
# EstimatedSalary    40
# Purchased          40
# dtype: int64

# %% [markdown]
# ## Working with columns

# %%
## Get column Names
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
## Get column labels
df.columns[0]
# Out:
# 'User ID'

# %% [markdown]
# To rename columns
#
# lets change the name of *Gender* column to *Sex*

# %%
df.rename(columns={'Gender':'Sex'},inplace=True)
df.head(2)
# Out:
#     User ID   Sex  Age  EstimatedSalary  Purchased
# 0  15624510  Male   19            19000          0
# 1  15810944  Male   35            20000          0

# %% [markdown]
# Using loops to rename a column can also be done as follows:

# %%
## Lets change Sex back to Gender
df.columns=['Gender' if x=='Sex' else x for x in df.columns]
df.head(2)
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %% [markdown]
#  $$cool..... 😎😎😎😎😎$$
